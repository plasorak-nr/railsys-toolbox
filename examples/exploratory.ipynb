# %%
# Out:
# Schema({'Row number': Int64, 'Simulation no.': String, 'Deadlock': Int64, 'Pattern': String, 'Train no.': String, 'Train name': String, 'Train class': String, 'Train category': Int64, 'Train formation ID': String, 'Abbreviation of train formation': String, 'Station index': Int64, 'Station abbreviation': String, 'Station name': String, 'Line abbr.': String, 'Route': String, 'Scheduled track': String, 'Actual track': String, 'Replatforming': Float64, 'Scheduled arrival': Time, 'Actual arrival': Time, 'SchedDep': Time, 'Actual departure': Time, 'Sched. run time': Int64, 'Total (scheduled run time)': Int64, 'Actual run time': Int64, 'Total (actual run time)': Int64, 'Scheduled travel time': Int64, 'Actual travel time': Int64, 'Scheduled dwell time': Int64, 'Actual dwell time': Int64, 'StopType': String, 'Change of direction of travel': Int64, 'Arrival lateness': Int64, 'Departure lateness': Int64, 'Difference scheduled arrival': Int64, 'Total (Difference scheduled arrival)': Int64, 'Diff
# ...
